# %%
import nltk 
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords

# %%
data = pd.read_csv('train.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3512 entries, 0 to 3511
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Context   3512 non-null   object
#  1   Response  3508 non-null   object
# dtypes: object(2)
# memory usage: 55.0+ KB

# %%
data.dropna(inplace=True)

# %%
nombres_conversations = len(data)
nombres_patients = data['Context'].nunique()
nombres_therapeutes = data['Response'].nunique()
print(f'Nombre de conversations : {nombres_conversations}')
print(f'Nombre de patients : {nombres_patients}')
print(f'Nombre de therapeutes : {nombres_therapeutes}')
# Out:
# Nombre de conversations : 3508
# Nombre de patients : 995
# Nombre de therapeutes : 2479

# %%
data["Context"] = data["Context"].str.lower()
data["Response"] = data["Response"].str.lower()

# %%
data["Context"] = data["Context"].str.replace('[^\w\s]', '',regex=True)
data["Response"] = data["Response"].str.replace('[^\w\s]', '',regex=True)

# %%
data["Context"] = data["Context"].str.replace('\d', '')
data["Response"] = data["Response"].str.replace('\d', '')

# %%
sw = stopwords.words('english')

# %%
def remove_stopwords(text):
    words = str(text).split()
    filtered_words = []
    for word in words:
        if word not in sw:
            filtered_words.append(word)
    return " ".join(filtered_words)

# %%
data["Context"] = data["Context"].apply(remove_stopwords)
data["Response"] = data["Response"].apply(remove_stopwords)

# %%
import re
def tokenization(text):
    return re.findall(r'\b\w+\b', text)

# %%
data['Context_tokens'] = data['Context'].astype(str).apply(tokenization)
data['Response_tokens'] = data['Response'].astype(str).apply(tokenization)

# %%
# Statistiques des mots
contextDic = []
responseDic = []
allDic = []
for word in data['Context_tokens']:
    contextDic.extend(word)
    allDic.extend(word)
for word in data['Response_tokens']:
    responseDic.extend(word)
    allDic.extend(word)
from collections import Counter
contextCounter = Counter(contextDic)
responseCounter = Counter(responseDic)
allCounter = Counter(allDic)

# %%
motsContext = contextCounter.most_common(100)
mots = []
frequences = []
for mot, freq in motsContext:
    mots.append(mot)
    frequences.append(freq)
for mot, freq in motsContext:
    print(f'{mot}: {freq}')
# Out:
# im: 2162
# feel: 1223
# dont: 1186
# like: 1150
# know: 973
# get: 901
# ive: 862
# want: 768
# years: 667
# time: 627
# never: 621
# always: 509
# really: 507
# relationship: 500
# cant: 490
# think: 437
# love: 428
# people: 425
# still: 424
# even: 420
# anxiety: 412
# things: 397
# help: 389
# life: 375
# counseling: 358
# issues: 344
# going: 343
# told: 340
# need: 331
# boyfriend: 330
# sex: 330
# depression: 314
# family: 314
# one: 314
# back: 313
# friends: 300
# much: 300
# would: 291
# feeling: 289
# go: 288
# lot: 286
# past: 285
# every: 283
# anything: 282
# someone: 276
# doesnt: 274
# something: 273
# many: 267
# together: 265
# talk: 261
# hes: 261
# stop: 260
# married: 259
# normal: 252
# husband: 250
# work: 246
# see: 243
# school: 235
# make: 234
# sometimes: 230
# day: 228
# ago: 225
# said: 223
# child: 223
# almost: 222
# says: 221
# got: 218
# times: 215
# wants: 212
# also: 211
# two: 210
# wrong: 210
# everything: 199
# long: 198
# history: 196
# say: 196
# parents: 196
# right: 196
# find: 193
# address: 192
# dad: 191
# year: 190
# since: 190
# away: 190
# way: 188
# live: 187
# makes: 184
# mom: 177
# home: 176
# us: 175
# months: 174
# around: 172
# thinking: 172
# shes: 171
# afraid: 171
# move: 170
# recently: 170
# angry: 169
# last: 169
# bad: 168

# %%
motsResponse = responseCounter.most_common(100)
mots = []
frequences = []
for mot, freq in motsResponse:
    mots.append(mot)
    frequences.append(freq)
for mot, freq in motsResponse:
    print(f'{mot}: {freq}')
# Out:
# may: 2900
# feel: 2689
# would: 2353
# help: 2286
# like: 2240
# relationship: 1905
# time: 1885
# people: 1765
# therapist: 1666
# know: 1581
# way: 1568
# one: 1558
# want: 1529
# also: 1421
# good: 1402
# life: 1330
# get: 1327
# things: 1324
# dont: 1260
# feeling: 1188
# need: 1173
# make: 1159
# someone: 1153
# work: 1152
# youre: 1107
# something: 1089
# find: 1088
# person: 1074
# feelings: 990
# see: 990
# many: 988
# could: 974
# therapy: 973
# might: 890
# first: 885
# talk: 876
# anxiety: 862
# able: 836
# take: 825
# important: 817
# think: 815
# best: 804
# right: 786
# really: 758
# even: 756
# try: 748
# thoughts: 740
# going: 738
# support: 736
# que: 732
# go: 718
# well: 704
# ask: 685
# us: 684
# counselor: 676
# de: 676
# different: 673
# change: 665
# others: 656
# counseling: 649
# love: 644
# start: 636
# often: 634
# question: 628
# say: 621
# sounds: 616
# helpful: 616
# new: 605
# whether: 599
# sometimes: 596
# family: 593
# give: 588
# understand: 586
# ways: 586
# lot: 582
# much: 581
# better: 580
# partner: 579
# issues: 574
# trust: 562
# im: 545
# tell: 540
# possible: 538
# consider: 536
# learn: 531
# situation: 530
# difficult: 522
# care: 522
# emotions: 514
# thing: 502
# part: 497
# doesnt: 483
# needs: 482
# depression: 475
# process: 473
# relationships: 471
# maybe: 469
# another: 469
# parents: 466
# look: 464

# %%
# Fréquence des mots dans chaque conversion pour les Contextes
data['Context_word_count'] = data['Context_tokens'].apply(len)
# Fréquence des mots dans chaque conversion pour les Réponses
data['Response_word_count'] = data['Response_tokens'].apply(len)

# %%
# %pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\lenovo\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\lenovo\anaconda3\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import Word # type: ignore
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data["Context"] = data["Context"].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data["Response"] = data["Response"].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
#Déterminer les sujets méthode 1 : 
stress = ['stress','pressure','tension','fatigue','restlessness','anxiety']
depression = ['depression','sadness','guilt','suicide','insomnia']

# %%
contexts = data.drop_duplicates(subset=["Context"])
def topic_detection(text,topic):
    n=0
    for sentence in text:
        words = sentence.split()
        count = 0
        for w in words:
            if w in topic:
                count+=1
        if count>0:
            n+=1
    return n

# %%
stress_count = topic_detection(contexts["Context"], stress)
depression_count = topic_detection(contexts["Context"], depression)
print(f"Stress count: {stress_count}")
print(f"Depression count: {depression_count}")
# Out:
# Stress count: 81
# Depression count: 63

# %%
# Déterminer les sujets méthode 2 :
from sklearn.feature_extraction.text import TfidfVectorizer
df = data["Context"]
vectorizer = TfidfVectorizer(max_features=1000,stop_words='english')
X = vectorizer.fit_transform(df)
feature_names = vectorizer.get_feature_names_out()

# %%
scores = np.mean(X.toarray(), axis=0)
top_words = sorted(zip(feature_names, scores), key=lambda x: x[1], reverse=True)
for word,score in top_words[:20]:
    print(word,score)
#Les sujets les plus fréquents sont : 
# Anxiété et dépression : im, help, anxiety
# Problèmes relationnels : relationship, year, love, friend 
# Perte de repères : feel, like, know
# Out:
# im 0.05600326264250003
# feel 0.04286010172511997
# dont 0.0386322277005551
# like 0.03811520892586371
# know 0.03634419640895322
# want 0.03223586850792436
# ive 0.029967247722900638
# time 0.028959717486148073
# year 0.027510493836719198
# people 0.0260392868135153
# counseling 0.02453600997339863
# really 0.023859763829913855
# relationship 0.023161793145832978
# feeling 0.020971224348010322
# thing 0.020815205269710303
# help 0.020582123705089602
# love 0.020374007323649874
# say 0.019371949222523246
# anxiety 0.019134087042585658
# friend 0.019122246221126876

# %%
# %pip install sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\lenovo\anaconda3\lib\site-packages (5.3.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (5.3.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\lenovo\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.9.1)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Déterminer les sujets méthode 3 :
from sentence_transformers import SentenceTransformer # type: ignore
from sklearn.cluster import KMeans
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(data['Context'].tolist())
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)
data['Topic'] = labels
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Afficher les sujets
for i in range(num_clusters):
    print(f"Sujet {i}:")
    texts = data[data['Topic'] == i]['Context']
    vectorizer = TfidfVectorizer(max_features=10, stop_words='english')
    X = vectorizer.fit_transform(texts)
    print(vectorizer.get_feature_names_out())
# Sujet 0 : Relations personnelles (Solitude)
# Sujet 1 : Problèmes de santé mentale (Anxiété et dépression)
# Sujet 2 : Demande de l'aide (Recherche de soutien et de conseils)
# Sujet 3 : Problèmes relationnels (Difficultés dans les relations amoureuses et amicales)
# Sujet 4 : Problèmes de passé (Traumatismes et expériences passées)
# Out:
# Sujet 0:
# ['dont' 'feel' 'friend' 'im' 'know' 'like' 'really' 'think' 'time' 'want']
# Sujet 1:
# ['anxiety' 'dont' 'feel' 'feeling' 'im' 'ive' 'like' 'normal' 'people'
#  'thought']
# Sujet 2:
# ['dont' 'feel' 'help' 'im' 'ive' 'know' 'like' 'time' 'want' 'year']
# Sujet 3:
# ['dont' 'feel' 'im' 'know' 'like' 'love' 'relationship' 'time' 'want'
#  'year']
# Sujet 4:
# ['address' 'counseling' 'depression' 'history' 'im' 'issue' 'ive' 'sexual'
#  'therapist' 'year']

# %%
# Déterminer les sujets méthode 4 :
from sklearn.decomposition import LatentDirichletAllocation
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
X = vectorizer.fit_transform(data['Context'])
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda.components_):
    print(f"Sujet {topic_idx}:")
    top_features_indices = topic.argsort()[:-11:-1]
    top_features = [feature_names[i] for i in top_features_indices]
    print(top_features)
# Out:
# Sujet 0:
# ['im', 'help', 'feel', 'people', 'really', 'want', 'know', 'dont', 'sex', 'life']
# Sujet 1:
# ['know', 'love', 'therapist', 'dont', 'child', 'year', 'im', 'need', 'want', 'like']
# Sujet 2:
# ['counseling', 'therapy', 'normal', 'ive', 'session', 'history', 'address', 'counselor', 'issue', 'client']
# Sujet 3:
# ['feel', 'im', 'like', 'day', 'want', 'told', 'dont', 'say', 'year', 'got']
# Sujet 4:
# ['im', 'feel', 'dont', 'feeling', 'anxiety', 'know', 'like', 'thought', 'thing', 'time']
